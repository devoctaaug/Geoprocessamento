# %% [markdown]
# ##Carregamento dos Dados

# %%
import numpy as np
import pandas as pd
import folium 
from folium.plugins import HeatMap, HeatMapWithTime

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#dados da utilização das bikes
df_bike= pd.read_csv('/content/df_rides.csv')
#dados das estações
df_station= pd.read_csv('/content/df_stations.csv')

# %% [markdown]
# ## Entendimento dos dados

# %%
df_bike.head()
# Out:
#   user_gender user_birthdate user_residence   ride_date time_start  time_end  \
# 0           M     1971-06-08            NaN  2018-01-01   06:05:18  06:21:33
# 1           M     1989-02-11             DF  2018-01-01   06:27:01  06:32:17
# 2           M     1968-07-19            NaN  2018-01-01   06:29:33  06:44:57
# 3           M     1991-12-19            NaN  2018-01-01   06:53:53  06:59:45
# 4           M     1969-03-03             DF  2018-01-01   06:58:56  17:40:04
#
#                      station_start  \
# 0                11 - Rodoviária 2
# 1         26 - Ministério da Saude
# 2                11 - Rodoviária 2
# 3  10 - Ministério dos Transportes
# 4                   15 - Brasil 21
#
#                                          station_end  ride_duration  ride_late
# 0                            41 - Instituto de Artes      16.250000        0.0
# 1  28 - CNMP - Conselho Nacional do Ministério Pú...       5.266667        0.0
# ...

# %%
df_bike.shape
# Out:
# (119256, 10)

# %%
df_bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119256 entries, 0 to 119255
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_gender     119144 non-null  object
#  1   user_birthdate  119255 non-null  object
#  2   user_residence  43733 non-null   object
#  3   ride_date       119256 non-null  object
#  4   time_start      119256 non-null  object
#  5   time_end        119256 non-null  object
#  6   station_start   119256 non-null  object
#  7   station_end     119256 non-null  object
#  8   ride_duration   89519 non-null   float64
#  9   ride_late       89519 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 9.1+ MB

# %%
df_bike.nunique()
# Out:
# user_gender           2
# user_birthdate     8615
# user_residence      247
# ride_date           128
# time_start        49921
# time_end          50258
# station_start        46
# station_end          47
# ride_duration      8364
# ride_late             2
# dtype: int64

# %%
sexo = df_bike['user_gender']
sexo.value_counts()
# Out:
# M    88884
# F    30260
# Name: user_gender, dtype: int64

# %%
df_station.head()
# Out:
#                      station  station_number            station_name  \
# 0            1 - Memorial JK               1             Memorial JK
# 1           2 - Praça Buriti               2            Praça Buriti
# 2   3 - Centro de Convenções               3    Centro de Convenções
# 3            4 - Torre de TV               4             Torre de TV
# 4  5 - Setor Hoteleiro Norte               5   Setor Hoteleiro Norte
#
#          lat        lon
# 0 -15.783479 -47.913372
# 1 -15.785651 -47.908750
# 2 -15.786409 -47.899865
# 3 -15.789581 -47.894312
# 4 -15.789029 -47.891015

# %%
df_station.shape
# Out:
# (49, 5)

# %%
df_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   station         49 non-null     object
#  1   station_number  49 non-null     int64
#  2   station_name    49 non-null     object
#  3   lat             49 non-null     float64
#  4   lon             49 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# ##Mapas

# %%
m = folium.Map(location=[-15.793889, -47.882778], zoom_start=11)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Marker(# Localização em coordenadas
              location=[ -15.797288893791357, -47.8754106539734],
              # Informação do Marcador no popup
              popup = 'Catedral Metropolitana de Brasília',
              # Configuramos o Icone do marcador
              icon=folium.Icon(
                  # Cor do Marcador
                  color='black',
                  # Fonte do icone
                  prefix='fa',
                  # Simbolo do marcador
                  icon='university'
              )
).add_to(m)

# %%
folium.Marker(# Localização em coordenadas
              location=[ -15.800251572810566, -47.86121133546193],
              # Informação do Marcador no popup
              popup = 'Praça dos Três Poderes',
              # Configuramos o Icone do marcador
              icon=folium.Icon(
                  # Cor do Marcador
                  color='black',
                  # Fonte do icone
                  prefix='fa',
                  # Simbolo do marcador
                  icon='university'
              )
).add_to(m)

# %%
folium.Marker(# Localização em coordenadas
              location=[ -15.789927843484884, -47.894341979608775],
              # Informação do Marcador no popup
              popup = 'Torre de TV',
              # Configuramos o Icone do marcador
              icon=folium.Icon(
                  # Cor do Marcador
                  color='black',
                  # Fonte do icone
                  prefix='fa',
                  # Simbolo do marcador
                  icon='university'
              )
).add_to(m)

# %%
folium.Marker(# Localização em coordenadas
              location=[ -15.784456053634658, -47.91346076482036],
              # Informação do Marcador no popup
              popup = 'Memorial JK',
              # Configuramos o Icone do marcador
              icon=folium.Icon(
                  # Cor do Marcador
                  color='black',
                  # Fonte do icone
                  prefix='fa',
                  # Simbolo do marcador
                  icon='university'
              )
).add_to(m)

# %%
folium.Marker(# Localização em coordenadas
              location=[ -15.783299731870137, -47.899191414277965],
              # Informação do Marcador no popup
              popup = 'Arena BRB',
              # Configuramos o Icone do marcador
              icon=folium.Icon(
                  # Cor do Marcador
                  color='black',
                  # Fonte do icone
                  prefix='fa',
                  # Simbolo do marcador
                  icon='university'
              )
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for index, i in df_station.iterrows():
    # objeto de marcador folium
    folium.Marker(
              # vamos utilizar as colunas Latitude e Longitude do dataset para criar o marcador
              location=[ i['lat'], i['lon']],
              # Informação do popup vai ser o nome da estação
              popup = str(i['station']),
              icon=folium.Icon(
                  color='red', 
                  icon='glyphicon glyphicon-send'
              )
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
